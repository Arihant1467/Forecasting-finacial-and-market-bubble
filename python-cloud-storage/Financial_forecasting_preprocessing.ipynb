# %%
# !pip install matplotlib
# !pip install numpy
# !pip install altair
# !pip install vega_datasets

# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pip install altair

# %%
# !pip install vega_datasets

# %%
import numpy as np
import pandas as pd
import altair as alt
from vega_datasets import data

data = pd.read_csv("LANDDATA-CSV.csv", encoding="ISO-8859-1")

alt.data_transformers.enable('json')
data.head(10)
# Out:
#        ï»¿ Unnamed: 1  \
# 0      MSA       Date
# 1  ATLANTA     1984Q4
# 2  ATLANTA     1985Q1
# 3  ATLANTA     1985Q2
# 4  ATLANTA     1985Q3
# 5  ATLANTA     1985Q4
# 6  ATLANTA     1986Q1
# 7  ATLANTA     1986Q2
# 8  ATLANTA     1986Q3
# 9  ATLANTA     1986Q4
#
#   All values, costs, and indexes are in current dollars (nominals)  \
# 0                                         Home Value
# 1                                            $92,559
# 2                                            $92,880
# 3                                            $92,928
# 4                                            $97,008
# 5                                            $98,530
# 6                                            $99,832
# 7                                           $101,380
# 8                                           $102,594
# 9                                           $104,131
#
#        Unnamed: 3  Unnamed: 4        Unnamed: 5        Unnamed: 6  \
# ...

# %%
data
# Out:
#                ï»¿ Unnamed: 1  \
# 0              MSA       Date
# 1          ATLANTA     1984Q4
# 2          ATLANTA     1985Q1
# 3          ATLANTA     1985Q2
# 4          ATLANTA     1985Q3
# ...            ...        ...
# 6206  WASHINGTONDC     2017Q2
# 6207  WASHINGTONDC     2017Q3
# 6208  WASHINGTONDC     2017Q4
# 6209  WASHINGTONDC     2018Q1
# 6210  WASHINGTONDC     2018Q2
#
#      All values, costs, and indexes are in current dollars (nominals)  \
# 0                                            Home Value
# 1                                               $92,559
# 2                                               $92,880
# 3                                               $92,928
# 4                                               $97,008
# ...                                                 ...
# 6206                                           $556,626
# 6207                                           $558,709
# 6208                                           $565,120
# ...

# %%
for col in data.columns: 
    print(col)
print()
print(data.dtypes)
print()
print("Is there a unique column?:", data.columns.is_unique)
# Out:
# ï»¿
# Unnamed: 1
# All values, costs, and indexes are in current dollars (nominals)
# Unnamed: 3
# Unnamed: 4
# Unnamed: 5
# Unnamed: 6
# Unnamed: 7
#
# ï»¿                                                                 object
# Unnamed: 1                                                          object
# All values, costs, and indexes are in current dollars (nominals)    object
# Unnamed: 3                                                          object
# Unnamed: 4                                                          object
# Unnamed: 5                                                          object
# Unnamed: 6                                                          object
# Unnamed: 7                                                          object
# dtype: object
#
# Is there a unique column?: True

# %%
data.columns = ['MSA','Date','Home Value',
                     'Structure Cost','Land Value','Land Share (Pct)','Home Price Index','Land Price Index']

# %%
data
# Out:
#                MSA    Date  Home Value  Structure Cost  Land Value  \
# 0              MSA    Date  Home Value  Structure Cost  Land Value
# 1          ATLANTA  1984Q4     $92,559         $67,164     $25,394
# 2          ATLANTA  1985Q1     $92,880         $67,876     $25,003
# 3          ATLANTA  1985Q2     $92,928         $68,491     $24,437
# 4          ATLANTA  1985Q3     $97,008         $69,069     $27,939
# ...            ...     ...         ...             ...         ...
# 6206  WASHINGTONDC  2017Q2    $556,626        $272,716    $283,910
# 6207  WASHINGTONDC  2017Q3    $558,709        $274,045    $284,665
# 6208  WASHINGTONDC  2017Q4    $565,120        $275,643    $289,476
# 6209  WASHINGTONDC  2018Q1    $570,734        $280,434    $290,300
# 6210  WASHINGTONDC  2018Q2    $573,452        $285,489    $287,963
#
#       Land Share (Pct)  Home Price Index  Land Price Index
# 0     Land Share (Pct)  Home Price Index  Land Price Index
# ...

# %%
data = data.iloc[1:]

# %%
data
# Out:
#                MSA    Date Home Value Structure Cost Land Value  \
# 1          ATLANTA  1984Q4    $92,559        $67,164    $25,394
# 2          ATLANTA  1985Q1    $92,880        $67,876    $25,003
# 3          ATLANTA  1985Q2    $92,928        $68,491    $24,437
# 4          ATLANTA  1985Q3    $97,008        $69,069    $27,939
# 5          ATLANTA  1985Q4    $98,530        $69,601    $28,929
# ...            ...     ...        ...            ...        ...
# 6206  WASHINGTONDC  2017Q2   $556,626       $272,716   $283,910
# 6207  WASHINGTONDC  2017Q3   $558,709       $274,045   $284,665
# 6208  WASHINGTONDC  2017Q4   $565,120       $275,643   $289,476
# 6209  WASHINGTONDC  2018Q1   $570,734       $280,434   $290,300
# 6210  WASHINGTONDC  2018Q2   $573,452       $285,489   $287,963
#
#      Land Share (Pct) Home Price Index Land Price Index
# 1               27.4%            0.537            0.327
# 2               26.9%            0.539            0.324
# ...

# %%
data.MSA.unique()
# Out:
# array(['ATLANTA', 'BALTIMORE', 'BIRMINGHAM', 'BOSTON', 'BUFFALO',
#        'CHARLOTTE', 'CHICAGO', 'CINCINNATI', 'CLEVELAND', 'COLUMBUS',
#        'DALLAS', 'DENVER', 'DETROIT', 'FORTWORTH', 'HARTFORD', 'HOUSTON',
#        'INDIANAPOLIS', 'KANSASCITY', 'LOSANGELES', 'MEMPHIS', 'MIAMI',
#        'MILWAUKEE', 'MINNEAPOLISSTPAUL', 'NEWORLEANS', 'NEWYORK',
#        'NORFOLK', 'OAKLAND', 'OKLAHOMACITY', 'PHILADELPHIA', 'PHOENIX',
#        'PITTSBURGH', 'PORTLAND', 'PROVIDENCE', 'ROCHESTER', 'SACRAMENTO',
#        'SALTLAKECITY', 'SANANTONIO', 'SANBERNADINO', 'SANDIEGO',
#        'SANFRANCISCO', 'SANJOSE', 'SANTAANA', 'SEATTLE', 'STLOUIS',
#        'TAMPA', 'WASHINGTONDC'], dtype=object)

# %%
data.Date.unique()
# Out:
# array(['1984Q4', '1985Q1', '1985Q2', '1985Q3', '1985Q4', '1986Q1',
#        '1986Q2', '1986Q3', '1986Q4', '1987Q1', '1987Q2', '1987Q3',
#        '1987Q4', '1988Q1', '1988Q2', '1988Q3', '1988Q4', '1989Q1',
#        '1989Q2', '1989Q3', '1989Q4', '1990Q1', '1990Q2', '1990Q3',
#        '1990Q4', '1991Q1', '1991Q2', '1991Q3', '1991Q4', '1992Q1',
#        '1992Q2', '1992Q3', '1992Q4', '1993Q1', '1993Q2', '1993Q3',
#        '1993Q4', '1994Q1', '1994Q2', '1994Q3', '1994Q4', '1995Q1',
#        '1995Q2', '1995Q3', '1995Q4', '1996Q1', '1996Q2', '1996Q3',
#        '1996Q4', '1997Q1', '1997Q2', '1997Q3', '1997Q4', '1998Q1',
#        '1998Q2', '1998Q3', '1998Q4', '1999Q1', '1999Q2', '1999Q3',
#        '1999Q4', '2000Q1', '2000Q2', '2000Q3', '2000Q4', '2001Q1',
#        '2001Q2', '2001Q3', '2001Q4', '2002Q1', '2002Q2', '2002Q3',
#        '2002Q4', '2003Q1', '2003Q2', '2003Q3', '2003Q4', '2004Q1',
#        '2004Q2', '2004Q3', '2004Q4', '2005Q1', '2005Q2', '2005Q3',
# ...

# %%
from pandas._libs.tslibs.timestamps import Timestamp

# %%
from plotnine import *
from plotnine.data import mpg
# %matplotlib inline

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
mpg.shape, data.shape, type(mpg), type(data)
# Out:
# ((234, 11),
#  (6210, 8),
#  pandas.core.frame.DataFrame,
#  pandas.core.frame.DataFrame)

# %%
(ggplot(data[:500])
 + aes(x = 'Date', y = 'Home Value', color = 'MSA')
 + geom_point()
 + labs(title = 'Date vs HomeValue', x='Date', y='HomeValue')
)
# Out:
# <ggplot: (319501993)>

# %%
import plotnine as p9

# %%
(p9.ggplot(data = data[:100],
           mapping=p9.aes(x='Date',
                          y='Home Value',
                          color='MSA'))
    + p9.geom_point(alpha=0.1)
)
# Out:
# <ggplot: (316772181)>

# %%
(p9.ggplot(data=data[:50],
           mapping=p9.aes(x='factor(Date)'))
    + p9.geom_bar()
)
# Out:
# <ggplot: (325467513)>

# %%
data[:3]
# Out:
#        MSA    Date Home Value Structure Cost Land Value Land Share (Pct)  \
# 1  ATLANTA  1984Q4    $92,559        $67,164    $25,394            27.4%
# 2  ATLANTA  1985Q1    $92,880        $67,876    $25,003            26.9%
# 3  ATLANTA  1985Q2    $92,928        $68,491    $24,437            26.3%
#
#   Home Price Index Land Price Index
# 1            0.537            0.327
# 2            0.539            0.324
# 3            0.539            0.319

# %%
import seaborn as sns
sns.set()

# %%
ax = sns.countplot(x = "Date", hue = "Home Value", data = data[:100])

# %%
from ggplot import *

# print(ggplot(data, aes(x='Date')) + \
#     geom_histogram())

# %%
#source = data.data()
#alt.data_transformers.disable_max_rows()


alt.Chart(data).mark_bar().encode(
    alt.X("Structure Cost:Q", bin=True),
    y="count()",
)

# %%
import json 
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline data = json.dumps({ "success":True, "data":[ { "record_id":258585618, "timestamp":"2018-01-21 22:34:34", "bytes":29466, } , { "record_id":258585604, "timestamp":"2018-01-21 22:33:14", "bytes":37892, } , { "record_id":258584399, "timestamp":"2018-01-21 22:37:40", "bytes":36396, } ] }) 
data = json.loads(data) 
dates = [i['timestamp'] for i in data["data"]] 
values = [i['bytes'] for i in data['data']] 
df = pd.DataFrame({'dates':dates, 'values':values}) 
df['dates'] = [pd.to_datetime(i) for i in df['dates']]
print(df.sort_values(by='dates')) 
#dates
#values 1 2018-01-21 22:33:14 37892 0 2018-01-21 22:34:34 29466 2 2018-01-21 22:37:40 36396
plt.bar(dates, values)

# %%
d = {"Land Value": [
           {
               "Rate": 92559,
               "Structure Cost": 67
           },
           {
               "Rate": 92880,
               "Structure Cost": 67
           }
]}

df = pd.DataFrame(d)
#print (df)
df.plot("Rate","Structure Cost")
# c=['Land Value','Home Value']
# pd.to_numeric(c, errors='ignore')
# df.plot(x='Land Value', y='Home Value')
